# %% [markdown]
# #import Dataset and Load all the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

award_df=pd.read_csv('golden_globe_awards.csv',usecols= [0,2,3,6])
award_df
# Out:
#       year_film  ceremony                                           category  \
# 0          1943         1  Best Performance by an Actress in a Supporting...
# 1          1943         1  Best Performance by an Actor in a Supporting R...
# 2          1943         1                     Best Director - Motion Picture
# 3          1943         1                                            Picture
# 4          1943         1                          Actress In A Leading Role
# ...         ...       ...                                                ...
# 7986       2019        77  Best Performance by an Actor in a Supporting R...
# 7987       2019        77  Best Performance by an Actor in a Supporting R...
# 7988       2019        77  Best Performance by an Actor in a Supporting R...
# 7989       2019        77                             Cecil B. deMille Award
# 7990       2019        77                                Carol Burnett Award
#
#         win
# 0      True
# 1      True
# ...

# %% [markdown]
# Show first 5 records of the dataset

# %%
import pandas as pd
award_df=pd.read_csv('golden_globe_awards.csv',usecols= [0,2,3,6])
award_df.head(5)
# Out:
#    year_film  ceremony                                           category  \
# 0       1943         1  Best Performance by an Actress in a Supporting...
# 1       1943         1  Best Performance by an Actor in a Supporting R...
# 2       1943         1                     Best Director - Motion Picture
# 3       1943         1                                            Picture
# 4       1943         1                          Actress In A Leading Role
#
#     win
# 0  True
# 1  True
# 2  True
# 3  True
# 4  True

# %% [markdown]
# Show last 5 records of the dataset

# %%
import pandas as pd
award_df=pd.read_csv('golden_globe_awards.csv',usecols= [0,2,3,6])
award_df.tail(5)
# Out:
#       year_film  ceremony                                           category  \
# 7986       2019        77  Best Performance by an Actor in a Supporting R...
# 7987       2019        77  Best Performance by an Actor in a Supporting R...
# 7988       2019        77  Best Performance by an Actor in a Supporting R...
# 7989       2019        77                             Cecil B. deMille Award
# 7990       2019        77                                Carol Burnett Award
#
#         win
# 7986  False
# 7987  False
# 7988  False
# 7989  False
# 7990  False

# %% [markdown]
# check column names

# %%
award_df=pd.read_csv('golden_globe_awards.csv')
for col in award_df.columns:
 print(col)
# Out:
# year_film
# year_award
# ceremony
# category
# nominee
# film
# win

# %% [markdown]
# Unique value

# %%
award_df=pd.read_csv('golden_globe_awards.csv')
award_df.nunique()
# Out:
# year_film       77
# year_award      77
# ceremony        77
# category        76
# nominee       4292
# film          3083
# win              2
# dtype: int64

# %% [markdown]
# check column names

# %%
import pandas as pd
award_df=pd.read_csv('golden_globe_awards.csv',usecols= [0,2,3,6])
shape = award_df.shape
print('\DataFrame Shape :', shape)
print('\nNumber of rows :', shape[0])
print('\nNumber of columns :', shape[1])
# Out:
# \DataFrame Shape : (7991, 4)
#
# Number of rows : 7991
#
# Number of columns : 4

# %% [markdown]
# Show the size of the data

# %%
award_df=pd.read_csv('golden_globe_awards.csv',usecols= [0,2,3,6])
award_df.size
# Out:
# 31964

# %% [markdown]
# Print the information about all the variables of the dataset

# %%
import pandas as pd
award_df=pd.read_csv('golden_globe_awards.csv',usecols= [0,2,3,6])
award_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year_film  7991 non-null   int64
#  1   ceremony   7991 non-null   int64
#  2   category   7991 non-null   object
#  3   win        7991 non-null   bool
# dtypes: bool(1), int64(2), object(1)
# memory usage: 195.2+ KB

# %% [markdown]
# Maximum value

# %%
import pandas as pd
award_df=pd.read_csv('golden_globe_awards.csv',usecols= [0,2,3,6])
award_df_max = award_df.max()
award_df_max
# Out:
# year_film                                       2019
# ceremony                                          77
# category     Television Special - Variety Or Musical
# win                                             True
# dtype: object

# %% [markdown]
# Minimum value

# %%
import pandas as pd
award_df=pd.read_csv('golden_globe_awards.csv',usecols= [0,2,3,6])
award_df_min = award_df.min()
award_df_min
# Out:
# year_film                       1943
# ceremony                           1
# category     Actor In A Leading Role
# win                            False
# dtype: object

# %% [markdown]
# Unique value

# %%
import pandas as pd
award_df=pd.read_csv('golden_globe_awards.csv',usecols= [0,2,3,6])
df = pd.DataFrame(award_df)
df.category.unique()
# Out:
# array(['Best Performance by an Actress in a Supporting Role in any Motion Picture',
#        'Best Performance by an Actor in a Supporting Role in any Motion Picture',
#        'Best Director - Motion Picture', 'Picture',
#        'Actress In A Leading Role', 'Actor In A Leading Role',
#        'Promoting International Understanding',
#        'Special Achievement Award', 'Best Screenplay - Motion Picture',
#        'Best Original Score - Motion Picture',
#        'New Star Of The Year - Actress', 'New Star Of The Year - Actor',
#        'Juvenile Performance', 'Cinematography',
#        'Foreign Film - English Language',
#        'Best Motion Picture - Foreign Language',
#        'Outstanding Use Of Color',
#        'Best Performance by an Actress in a Motion Picture - Drama',
#        'Best Performance by an Actor in a Motion Picture - Drama',
#        'Best Performance by an Actor in a Motion Picture - Musical or Comedy',
#        'New Star Of The Year',
# ...

# %% [markdown]
# Check the missing value

# %%
award_df.isnull().values.any()
# Out:
# False

# %% [markdown]
# How many missing values are present

# %%
award_df.isnull().values.sum()
# Out:
# 0

# %% [markdown]
# Check category name

# %%
award_df[award_df["category"]=="Actor In A Leading Role"]
# Out:
#     year_film  ceremony                 category    win
# 5        1943         1  Actor In A Leading Role   True
# 11       1944         2  Actor In A Leading Role   True
# 18       1945         3  Actor In A Leading Role   True
# 26       1946         4  Actor In A Leading Role   True
# 38       1947         5  Actor In A Leading Role   True
# 50       1948         6  Actor In A Leading Role   True
# 77       1949         7  Actor In A Leading Role   True
# 78       1949         7  Actor In A Leading Role  False

# %% [markdown]
# Check Year_film years.

# %%
df = pd.read_csv('golden_globe_awards.csv')
df = df.dropna(how = 'all')
df.drop(df[df['year_film'] > 1950].index, inplace = True)
print(df.head(15))
print(df.shape)
# Out:
#     year_film  year_award  ceremony  \
# 0        1943        1944         1
# 1        1943        1944         1
# 2        1943        1944         1
# 3        1943        1944         1
# 4        1943        1944         1
# 5        1943        1944         1
# 6        1944        1945         2
# 7        1944        1945         2
# 8        1944        1945         2
# 9        1944        1945         2
# 10       1944        1945         2
# 11       1944        1945         2
# 12       1945        1946         3
# 13       1945        1946         3
# 14       1945        1946         3
#
#                                              category                 nominee  \
# 0   Best Performance by an Actress in a Supporting...          Katina Paxinou
# 1   Best Performance by an Actor in a Supporting R...           Akim Tamiroff
# 2                      Best Director - Motion Picture              Henry King
# ...

# %% [markdown]
# Data Vizualization

# %%
df = pd.DataFrame(award_df['win'].groupby(award_df['category']).sum())
df.plot(kind= 'bar')
plt.show()

# %%
df = df.reset_index()
sns.barplot(x = df['win'], y = df['category'])

# %%
award_df.category.value_counts(normalize=True)
award_df.category.value_counts(normalize=True).plot.pie()
plt.show()

# %%
plt.scatter(df.category,df.win)
plt.show()

# %%
import seaborn as sns
sns.pairplot(data = df, vars=['category','win'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:88: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,2)
plt.title("",fontsize=20)
sns.countplot('win',data=df)
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,2)
plt.title("",fontsize=20)
sns.countplot('category',data=df)
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   import sys

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
award_df = pd.read_csv('golden_globe_awards.csv')
df.head()
df.boxplot(by ='category', column =['win'], grid = True )
